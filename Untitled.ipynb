# %%
import pandas as pd
import os
import tarfile
import urllib.request

# %%
Startups = pd.read_csv('50_Startups.csv')

# %%
df = pd.DataFrame(Startups)

# %%
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-2a851eda2e88> in <module>
# ----> 1 print(df)
#
# NameError: name 'df' is not defined
